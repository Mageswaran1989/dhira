# %% [markdown]
# # REINFORCEMENT LEARNING (RL) – POLICY GRADIENTS
#
# - https://theneuralperspective.com/2016/11/25/reinforcement-learning-rl-policy-gradients-i/
# - https://github.com/ashutoshkrjha/Cartpole-OpenAI-Tensorflow/blob/master/cartpole.py
# - https://gist.github.com/shanest/535acf4c62ee2a71da498281c2dfc4f4

# %% [markdown]
# ### OBJECTIVE
#
# The three main components in our model include the state, action and reward. The state can be thought of the environment which generates an action which leads to a reward. Actions can also alter the state and often the reward may be delayed and not always an immediate response to a given action.
#
# ```
#                -----------------
#               |                 |
#              \ /                |
#               -                 |
#             State-----------> Action-----------> Reward
#               |                                    -
#               |                                   / \
#               |                                    |
#               --------------------------------------
# ```

# %% [markdown]
# s  ---> state
# a  ---> action
# a* ---> correct action
# r  ---> reward
# $\pi$  ---> policy
# $\theta$  --->  policy weights
# R ---> total reward
# $\hat A $  ---> Advantage Est
# $\gamma$  ---> discount factor
#
# $max_\theta \sum_{n=1}^{N}\ \log P(y_n|x_n;\theta)$
# = $max_\theta \sum_{n=1}^{N}\ \log P(a^*_n|s_n;\theta)$
# = $min_\theta \big[- \sum_{n=1}^{N}\ \log P(a^*_n|s_n;\theta)\big]$
#
# Since we don’t have the correction actions to take, the best we can do it try some actions that may turn our good/bad and then eventually train our policy weights (theta) so that we increase the chances of the good actions. One common approach is to collect a series of states, actions and the corresponding rewards (s0, a0, r0, s1, a1, r1, … ) and from this we can calculate R, the total reward – sum of all the rewards r. This will give us the policy gradient:
#
# $$
# \frac{\partial J}{\partial \theta} = \frac{\partial \sum \log \pi (a|s;\theta)}{\partial \theta} R
# $$

# %% [markdown]
# We will take a closer look at why this policy gradient is expressed as it is later in the section where we draw parallels with supervised learning.
#
# When calculating the total reward R for an episode (series of events), we will have good and bad actions. But, according to our policy gradient, we will be updating the weights to favor ALL the actions in a given episode if the reward is positive and the magnitude of the update depends on the magnitude of the gradient. When we repeat this with enough episodes, our policy gradient becomes quite precise in modeling what actions to take given a state in order to maximize the reward.
#
# There are several additions we can make to our policy gradient, such as adding on an advantage estimator to determine which specific actions were good/bad instead of just using the total reward to judge an episode as good/bad.

# %% [markdown]
# So how does this supervised learning technique relate to reinforcement learning policy gradients? If you inspect the loss functions, you will see that they are exactly the same in principle. The negative log likelihood loss function above is the simplification of the multi-class cross entropy loss function below.
#
# $$
# J(\theta) = - \sum_i y_i ln(\hat y_i)
# $$
#
# Eg:
# Computed($\hat y$): [0.3,0.3,0.4]
# Targets ($y$) : [0,0,1]
# $$
# J(\theta) = -  [0 * ln(0.3) + 0 * ln(0.3) + 1 * ln(0.4)] = - ln(0.4)
# $$
#
# With the multinomial cross entropy, you can see that we only keep the loss contribution from the correct class. Usually, with neural nets, this will be case if our ouputs are sparse (just 1 true class). Therefore, we can rewrite our loss into just a $\sum(-log(\hat y))$ where y_hat will just be the probability of the correct class. We just replace $y_i$ (true y) with 1 and for the probabilities for the other classes, doesn’t matter because their $y_i$ is 0. This is referred to as negative log likelihood. But for drawing the parallel between supervised learning and RL, let’s keep it in the explicit cross-entropy form.
#
# Supervised: $J(\theta) = - \sum y_i \log (\hat y_i)$
# Reninforcement: $J(\theta) = - \sum r \log \pi (a|s;\theta)$
#
#
# In supervised learning, we have a prediction ($\hat y$) and a true label ($y_i$). In a typical case, only one label will be 1 (true) in $y_i$, so therefore only the log of the true class’s prediction will be taken into account. But as we saw above, the gradient will take into account the predicted probability for all the classes. In RL, we have our action (a) based on our policy ($\pi$) which we take the log of. We multiply the action from the policy with our reward for that action.
#
# Note: The action is a number from the outputs (ex. chosen action is 2, so we take the 0.9 from  [0.2, 0.3, 0.9, 0.1] to put into the log . The reward can be any magnitude and direction but like our supervised case, it will help determine the loss and properly adjust the weights by influencing the gradient. If the reward is positive, the weights will be altered via the gradient in order to favor the action that was made in that state. If the reward is negative, the gradient will be unfavored to make that action with that particular state. DO NOT draw parallels by saying the reward is like $y_i$ because, as you can see, that is not the case.

# %% [markdown]
# ### NUANCES
#
# You may notice that we do an additional operation to our rewards before feeding it in for training. We do what’s known as discounting the reward. The idea is that each reward will be weighted by all the rewards that follow it since the action responsible for the current reward will determine the rewards for the subsequent events. We weight each reward by the discount factor gamma^(time since reward). So each reward will be recalculated by the following expression:
#
# $$
# r_t = \sum_{k=0}^{\infty} \gamma ^ k r_{t+1}
# $$

# %% [markdown]
# https://gym.openai.com/docs

# %%
import gym
import time
env = gym.make('CartPole-v0')
env.reset()
total_reward = 0
for _ in range(1000):
    env.render()
    time.sleep(0.01)
    observation, reward, done, info = env.step(env.action_space.sample()) # take a random action
    total_reward += reward
    if done: break
env.close()

print('Total Reward is:', total_reward)
# Out:
# [2017-09-06 19:43:36,715] Making new env: CartPole-v0
# Total Reward is: 13.0

# %%
#possible actions available
for i in range(20):
    print(env.action_space.sample(), end=' ')

# %%
print(env.action_space)
#> Discrete(2) i.e valid actions are either 0 or 1. 
print(env.observation_space)
#> Box(4,)
print(env.observation_space.high)
#> array([ 2.4       ,         inf,  0.20943951,         inf])
print(env.observation_space.low)
#> array([-2.4       ,        -inf, -0.20943951,        -inf])

# %%
# from gym import envs
# avaiable_envs = envs.registry.all()
# [print(each) for each in list(avaiable_envs)]

# %%
import gym
env = gym.make('CartPole-v0')

input_initial = env.reset()

print('input_initial: ', input_initial)
for i_episode in range(10):
    total_reward = 0
    observation = env.reset()
    for t in range(1000):
        env.render()
        time.sleep(0.01)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        total_reward += reward
        if done:
            
#             print(observation, reward, done, info )
            print("Episode finished after {} timesteps with score {}".format(t+1, total_reward))
            break
env.close()
# Out:
# [2017-09-06 19:47:39,126] Making new env: CartPole-v0
# input_initial:  [-0.04124413  0.03330742  0.02792075 -0.00368043]
# Episode finished after 36 timesteps with score 36.0
# Episode finished after 43 timesteps with score 43.0
# Episode finished after 32 timesteps with score 32.0
# Episode finished after 23 timesteps with score 23.0
# Episode finished after 10 timesteps with score 10.0
# Episode finished after 11 timesteps with score 11.0
# Episode finished after 14 timesteps with score 14.0
# Episode finished after 22 timesteps with score 22.0
# Episode finished after 22 timesteps with score 22.0
# Episode finished after 23 timesteps with score 23.0

# %%
import sys
import numpy as np
import json
import os, inspect
import math
sys.path.append("../")
# %load_ext autoreload
# %autoreload 2
import logging
logger = logging.getLogger(__name__)

# %%
from dhira.data.openai.cartpole import CartPole as GymEnv
from dhira.tf.models.rl.cartpole import PolicyGradient as Model
from dhira.data.features.internal.feature_base import FeatureBase

# %%
try:
    if env is not None: env.close()
except:
    print('Env not yet defined')
rl = Model()
rl.compile()
env = GymEnv()
# Out:
# [2017-09-06 19:48:52,591] Making new env: CartPole-v0

# %%
rl.train_gym(env, batch_size=5,
              num_episodes=10000,
              expected_reward=200)
# Out:
# Episode:5 Average reward for episode:15.800000  Total average reward:15.800000
# Episode:10 Average reward for episode:19.400000  Total average reward:19.400000
# Episode:15 Average reward for episode:23.600000  Total average reward:23.600000
# Episode:20 Average reward for episode:14.000000  Total average reward:14.000000
# Episode:25 Average reward for episode:20.000000  Total average reward:20.000000
# Episode:30 Average reward for episode:27.600000  Total average reward:27.600000
# Episode:35 Average reward for episode:23.400000  Total average reward:23.400000
# Episode:40 Average reward for episode:18.000000  Total average reward:18.000000
# Episode:45 Average reward for episode:23.600000  Total average reward:23.600000
# Episode:50 Average reward for episode:16.000000  Total average reward:16.000000
# Episode:55 Average reward for episode:14.800000  Total average reward:14.800000
# Episode:60 Average reward for episode:13.000000  Total average reward:13.000000
# Episode:65 Average reward for episode:12.200000  Total average reward:12.200000
# Episode:70 Average reward for episode:14.200000  Total average reward:14.200000
# Episode:75 Average reward for episode:20.600000  Total average reward:20.600000
# Episode:80 Average reward for episode:21.800000  Total average reward:21.800000
# Episode:85 Average reward for episode:26.600000  Total average reward:26.600000
# Episode:90 Average reward for episode:15.800000  Total average reward:15.800000
# Episode:95 Average reward for episode:12.800000  Total average reward:12.800000
# Episode:100 Average reward for episode:15.600000  Total average reward:15.600000
# Episode:105 Average reward for episode:16.600000  Total average reward:16.600000
# Episode:110 Average reward for episode:21.000000  Total average reward:21.000000
# Episode:115 Average reward for episode:12.600000  Total average reward:12.600000
# Episode:120 Average reward for episode:15.400000  Total average reward:15.400000
# Episode:125 Average reward for episode:15.200000  Total average reward:15.200000
# Episode:130 Average reward for episode:11.600000  Total average reward:11.600000
# Episode:135 Average reward for episode:14.400000  Total average reward:14.400000
# Episode:140 Average reward for episode:14.200000  Total average reward:14.200000
# Episode:145 Average reward for episode:15.800000  Total average reward:15.800000
# Episode:150 Average reward for episode:15.600000  Total average reward:15.600000
# Episode:155 Average reward for episode:15.600000  Total average reward:15.600000
# Episode:160 Average reward for episode:14.200000  Total average reward:14.200000
# Episode:165 Average reward for episode:15.600000  Total average reward:15.600000
# Episode:170 Average reward for episode:16.200000  Total average reward:16.200000
# Episode:175 Average reward for episode:14.400000  Total average reward:14.400000
# Episode:180 Average reward for episode:16.000000  Total average reward:16.000000
# Episode:185 Average reward for episode:14.600000  Total average reward:14.600000
# Episode:190 Average reward for episode:15.000000  Total average reward:15.000000
# Episode:195 Average reward for episode:20.200000  Total average reward:20.200000
# Episode:200 Average reward for episode:13.400000  Total average reward:13.400000
# Episode:205 Average reward for episode:11.000000  Total average reward:11.000000
# Episode:210 Average reward for episode:13.400000  Total average reward:13.400000
# Episode:215 Average reward for episode:14.000000  Total average reward:14.000000
# Episode:220 Average reward for episode:15.200000  Total average reward:15.200000
# Episode:225 Average reward for episode:22.800000  Total average reward:22.800000
# Episode:230 Average reward for episode:14.200000  Total average reward:14.200000
# Episode:235 Average reward for episode:16.800000  Total average reward:16.800000
# Episode:240 Average reward for episode:16.400000  Total average reward:16.400000
# Episode:245 Average reward for episode:13.600000  Total average reward:13.600000
# Episode:250 Average reward for episode:15.400000  Total average reward:15.400000
# Episode:255 Average reward for episode:18.000000  Total average reward:18.000000
# Episode:260 Average reward for episode:13.600000  Total average reward:13.600000
# Episode:265 Average reward for episode:13.800000  Total average reward:13.800000
# Episode:270 Average reward for episode:16.200000  Total average reward:16.200000
# Episode:275 Average reward for episode:14.000000  Total average reward:14.000000
# Episode:280 Average reward for episode:17.000000  Total average reward:17.000000
# Episode:285 Average reward for episode:13.600000  Total average reward:13.600000
# Episode:290 Average reward for episode:13.000000  Total average reward:13.000000
# Episode:295 Average reward for episode:18.200000  Total average reward:18.200000
# Episode:300 Average reward for episode:15.800000  Total average reward:15.800000
# Episode:305 Average reward for episode:14.600000  Total average reward:14.600000
# Episode:310 Average reward for episode:19.000000  Total average reward:19.000000
# Episode:315 Average reward for episode:15.000000  Total average reward:15.000000
# Episode:320 Average reward for episode:13.800000  Total average reward:13.800000
# Episode:325 Average reward for episode:13.000000  Total average reward:13.000000
# Episode:330 Average reward for episode:16.200000  Total average reward:16.200000
# Episode:335 Average reward for episode:14.800000  Total average reward:14.800000
# Episode:340 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:345 Average reward for episode:14.400000  Total average reward:14.400000
# Episode:350 Average reward for episode:21.400000  Total average reward:21.400000
# Episode:355 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:360 Average reward for episode:12.400000  Total average reward:12.400000
# Episode:365 Average reward for episode:14.600000  Total average reward:14.600000
# Episode:370 Average reward for episode:11.200000  Total average reward:11.200000
# Episode:375 Average reward for episode:12.600000  Total average reward:12.600000
# Episode:380 Average reward for episode:12.000000  Total average reward:12.000000
# Episode:385 Average reward for episode:15.800000  Total average reward:15.800000
# Episode:390 Average reward for episode:13.400000  Total average reward:13.400000
# Episode:395 Average reward for episode:18.200000  Total average reward:18.200000
# Episode:400 Average reward for episode:13.400000  Total average reward:13.400000
# Episode:405 Average reward for episode:15.200000  Total average reward:15.200000
# Episode:410 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:415 Average reward for episode:11.200000  Total average reward:11.200000
# Episode:420 Average reward for episode:16.800000  Total average reward:16.800000
# Episode:425 Average reward for episode:12.200000  Total average reward:12.200000
# Episode:430 Average reward for episode:12.800000  Total average reward:12.800000
# Episode:435 Average reward for episode:15.200000  Total average reward:15.200000
# Episode:440 Average reward for episode:11.400000  Total average reward:11.400000
# Episode:445 Average reward for episode:14.000000  Total average reward:14.000000
# Episode:450 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:455 Average reward for episode:12.800000  Total average reward:12.800000
# Episode:460 Average reward for episode:11.600000  Total average reward:11.600000
# Episode:465 Average reward for episode:11.600000  Total average reward:11.600000
# Episode:470 Average reward for episode:11.800000  Total average reward:11.800000
# Episode:475 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:480 Average reward for episode:14.600000  Total average reward:14.600000
# Episode:485 Average reward for episode:11.800000  Total average reward:11.800000
# Episode:490 Average reward for episode:12.200000  Total average reward:12.200000
# Episode:495 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:500 Average reward for episode:12.400000  Total average reward:12.400000
# Episode:505 Average reward for episode:11.600000  Total average reward:11.600000
# Episode:510 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:515 Average reward for episode:13.000000  Total average reward:13.000000
# Episode:520 Average reward for episode:11.800000  Total average reward:11.800000
# Episode:525 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:530 Average reward for episode:13.800000  Total average reward:13.800000
# Episode:535 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:540 Average reward for episode:11.000000  Total average reward:11.000000
# Episode:545 Average reward for episode:11.800000  Total average reward:11.800000
# Episode:550 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:555 Average reward for episode:11.400000  Total average reward:11.400000
# Episode:560 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:565 Average reward for episode:11.800000  Total average reward:11.800000
# Episode:570 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:575 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:580 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:585 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:590 Average reward for episode:11.400000  Total average reward:11.400000
# Episode:595 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:600 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:605 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:610 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:615 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:620 Average reward for episode:12.200000  Total average reward:12.200000
# Episode:625 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:630 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:635 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:640 Average reward for episode:11.000000  Total average reward:11.000000
# Episode:645 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:650 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:655 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:660 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:665 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:670 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:675 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:680 Average reward for episode:11.200000  Total average reward:11.200000
# Episode:685 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:690 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:695 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:700 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:705 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:710 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:715 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:720 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:725 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:730 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:735 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:740 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:745 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:750 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:755 Average reward for episode:11.400000  Total average reward:11.400000
# Episode:760 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:765 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:770 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:775 Average reward for episode:11.200000  Total average reward:11.200000
# Episode:780 Average reward for episode:8.400000  Total average reward:8.400000
# Episode:785 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:790 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:795 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:800 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:805 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:810 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:815 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:820 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:825 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:830 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:835 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:840 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:845 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:850 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:855 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:860 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:865 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:870 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:875 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:880 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:885 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:890 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:895 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:900 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:905 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:910 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:915 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:920 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:925 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:930 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:935 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:940 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:945 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:950 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:955 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:960 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:965 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:970 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:975 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:980 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:985 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:990 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:995 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1000 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1005 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1010 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1015 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:1020 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1025 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1030 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1035 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1040 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1045 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1050 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1055 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1060 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1065 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1070 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1075 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1080 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1085 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1090 Average reward for episode:12.600000  Total average reward:12.600000
# Episode:1095 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1100 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1105 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1110 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:1115 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:1120 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1125 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1130 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1135 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1140 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1145 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1150 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1155 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1160 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1165 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1170 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1175 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1180 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1185 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1190 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1195 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1200 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1205 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1210 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1215 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1220 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1225 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1230 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1235 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:1240 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1245 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:1250 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1255 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1260 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1265 Average reward for episode:10.600000  Total average reward:10.600000
# Episode:1270 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1275 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1280 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1285 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1290 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1295 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1300 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1305 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1310 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1315 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1320 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1325 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1330 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1335 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1340 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1345 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1350 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1355 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1360 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1365 Average reward for episode:8.600000  Total average reward:8.600000
# Episode:1370 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1375 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1380 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1385 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1390 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1395 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1400 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1405 Average reward for episode:8.600000  Total average reward:8.600000
# Episode:1410 Average reward for episode:11.400000  Total average reward:11.400000
# Episode:1415 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1420 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1425 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1430 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1435 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1440 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1445 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1450 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1455 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1460 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1465 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1470 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1475 Average reward for episode:8.600000  Total average reward:8.600000
# Episode:1480 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1485 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1490 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1495 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1500 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1505 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1510 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1515 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1520 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1525 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1530 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1535 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1540 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1545 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1550 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1555 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1560 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1565 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1570 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1575 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1580 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1585 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1590 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:1595 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1600 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1605 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:1610 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1615 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1620 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1625 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1630 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1635 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1640 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1645 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1650 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1655 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1660 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1665 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1670 Average reward for episode:10.800000  Total average reward:10.800000
# Episode:1675 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1680 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1685 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1690 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1695 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1700 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:1705 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1710 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1715 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1720 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1725 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1730 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1735 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1740 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1745 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1750 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1755 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1760 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1765 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:1770 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1775 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1780 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1785 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1790 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1795 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1800 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1805 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1810 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1815 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1820 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1825 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:1830 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1835 Average reward for episode:8.600000  Total average reward:8.600000
# Episode:1840 Average reward for episode:10.400000  Total average reward:10.400000
# Episode:1845 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1850 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1855 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1860 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1865 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1870 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1875 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1880 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1885 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1890 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1895 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1900 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1905 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:1910 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:1915 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1920 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1925 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1930 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1935 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1940 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1945 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:1950 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1955 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1960 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1965 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:1970 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:1975 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1980 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1985 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:1990 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:1995 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2000 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2005 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2010 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2015 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2020 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2025 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2030 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2035 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2040 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:2045 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2050 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:2055 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2060 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2065 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2070 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2075 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2080 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2085 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2090 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2095 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2100 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2105 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2110 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2115 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:2120 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2125 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:2130 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2135 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2140 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2145 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2150 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2155 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:2160 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2165 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2170 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2175 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2180 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2185 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2190 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2195 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2200 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2205 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2210 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2215 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2220 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2225 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2230 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2235 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2240 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2245 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2250 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2255 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2260 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2265 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2270 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2275 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2280 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2285 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2290 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2295 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2300 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2305 Average reward for episode:8.600000  Total average reward:8.600000
# Episode:2310 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2315 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2320 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2325 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2330 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2335 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2340 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2345 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2350 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2355 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2360 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2365 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:2370 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2375 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2380 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2385 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2390 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2395 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:2400 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2405 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2410 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2415 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2420 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2425 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2430 Average reward for episode:10.200000  Total average reward:10.200000
# Episode:2435 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2440 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2445 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2450 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2455 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2460 Average reward for episode:10.000000  Total average reward:10.000000
# Episode:2465 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2470 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2475 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2480 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2485 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2490 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2495 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2500 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2505 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2510 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2515 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2520 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2525 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2530 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2535 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2540 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2545 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2550 Average reward for episode:9.200000  Total average reward:9.200000
# Episode:2555 Average reward for episode:8.800000  Total average reward:8.800000
# Episode:2560 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2565 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2570 Average reward for episode:9.000000  Total average reward:9.000000
# Episode:2575 Average reward for episode:9.800000  Total average reward:9.800000
# Episode:2580 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2585 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2590 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2595 Average reward for episode:9.400000  Total average reward:9.400000
# Episode:2600 Average reward for episode:9.600000  Total average reward:9.600000
# Episode:2605 Average reward for episode:8.600000  Total average reward:8.600000

# %%
np.random.uniform()
