# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
import helper
help(helper.display_stats)
# Out:
# Help on function display_stats in module helper:
#
# display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
#     Display Stats of the the dataset

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function 
    minV = np.min(x)
    maxV = np.max(x)
    ret = (x - minV)/maxV
    return ret


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
np.zeros([2,3])
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  0.,  0.]])

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
#     print(type(x))
    x_shape = len(x)
    a = np.zeros([x_shape, 10])
    for i, label in enumerate(x): 
        np.put(a[i],label,1)
#     print(a[0])
    return np.array(a).reshape([x_shape, 10])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    assert(len(image_shape) == 3)
    ph = tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name="x")
    return ph


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    ph = tf.placeholder(tf.float32, shape=(None, n_classes), name="y")
    return ph



def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability
    """
    # TODO: Implement Function
    ph = tf.placeholder(tf.float32, shape=(None), name="keep_prob")
    return ph



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
DEBUG_FLAG_ = True

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    #equivalent to y intercept
    #constant value carried over across matrix math
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %%
test_x = tf.placeholder(tf.float32, [None, 32, 32, 5])
xx_shape = test_x.get_shape()
assert(len(xx_shape) == 4)
print(xx_shape[3])
print(type(xx_shape[3]))
print(xx_shape[3].value)
print(type(xx_shape[3].value))

print(xx_shape[1:4])
print(type(xx_shape[1:4]))
# Out:
# 5
# <class 'tensorflow.python.framework.tensor_shape.Dimension'>
# 5
# <class 'int'>
# (32, 32, 5)
# <class 'tensorflow.python.framework.tensor_shape.TensorShape'>

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    if(DEBUG_FLAG_): print("Creating conv2d_maxpool layer")
    num_input_channel = x_tensor.get_shape()
    assert(len(num_input_channel) == 4)
    shape = [conv_ksize[0], conv_ksize[1], num_input_channel[3].value, conv_num_outputs]
#     print(shape)
#     print(type(shape))
    weights = new_weights(shape=shape)
    biases = new_biases(length=conv_num_outputs)
    
    layer = tf.nn.conv2d(input=x_tensor,
                         filter=weights,
                         strides=[1, conv_strides[0], conv_strides[1], 1],
                         padding='SAME')
    if(DEBUG_FLAG_): print("   ---> conv layer: ", layer.get_shape())
    layer += biases
    
    layer = tf.nn.relu(layer)
    if(DEBUG_FLAG_): print("   ---> relu layer: ", layer.get_shape())
    
    layer = tf.nn.max_pool(value=layer,
                               ksize=[1, pool_ksize[0], pool_ksize[1], 1],
                               strides=[1, pool_strides[0], pool_strides[1], 1],
                               padding='SAME')
    if(DEBUG_FLAG_): print("   ---> max pool layer: ", layer.get_shape())
    
    return layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Creating conv2d_maxpool layer
#    ---> conv layer:  (?, 8, 8, 10)
#    ---> relu layer:  (?, 8, 8, 10)
#    ---> max pool layer:  (?, 4, 4, 10)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    layer_shape = x_tensor.get_shape()
    num_features = layer_shape[1:4].num_elements()
    layer_flat = tf.reshape(x_tensor, [-1, num_features])
    
    return layer_flat


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape()
    assert(len(x_shape) == 2)
    num_inputs = x_shape[1].value
     # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(x_tensor, weights) + biases
    layer = tf.nn.relu(layer) ### TODO should this be softmax?
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape()
    assert(len(x_shape) == 2)
    num_inputs = x_shape[1].value
     # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(x_tensor, weights) + biases
    
    return layer



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    shape = x.get_shape()
    assert(len(shape) == 4)
    batch = shape[0].value
    rows = shape[1].value
    cols = shape[2].value
    channel = shape[3].value
    
    conv_num_outputs = 32
    conv_ksize = (5, 5)
    conv_strides = (1, 1)
    pool_ksize = (2, 2)
    pool_strides = (2, 2)
    
    num_outputs = 10 #number of classes
    
    if(DEBUG_FLAG_): print("x: ", x.get_shape())
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer = conv2d_maxpool(x, 16, conv_ksize, conv_strides, pool_ksize, pool_strides)
    if(DEBUG_FLAG_): print("conv1 layer: ", layer.get_shape())
    layer = tf.nn.dropout(layer, keep_prob)
    if(DEBUG_FLAG_): print("conv1_dropout layer: ", layer.get_shape())
    layer = conv2d_maxpool(layer, 32, conv_ksize, conv_strides, pool_ksize, pool_strides)
    if(DEBUG_FLAG_): print("conv2 layer: ", layer.get_shape())


    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    layer = flatten(layer)
    if(DEBUG_FLAG_): print("flatten layer: ", layer.get_shape())
    layer = tf.nn.dropout(layer, keep_prob)
    if(DEBUG_FLAG_): print("flatten_dropout layer : ", layer.get_shape())

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer = fully_conn(layer, 1024)
    if(DEBUG_FLAG_): print("fully_connected1 layer: ", layer.get_shape())
#     layer = fully_conn(layer, 512)
#     if(DEBUG_FLAG_): print("fully_connected2 layer: ", layer.get_shape())
#     layer = fully_conn(layer, num_outputs)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    layer = output(layer, num_outputs)
    if(DEBUG_FLAG_): print("output layer: ", layer.get_shape(), "\n")
    
    
    # TODO: return output
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# x:  (?, 32, 32, 3)
# Creating conv2d_maxpool layer
#    ---> conv layer:  (?, 32, 32, 16)
#    ---> relu layer:  (?, 32, 32, 16)
#    ---> max pool layer:  (?, 16, 16, 16)
# conv1 layer:  (?, 16, 16, 16)
# conv1_dropout layer:  (?, 16, 16, 16)
# Creating conv2d_maxpool layer
#    ---> conv layer:  (?, 16, 16, 32)
#    ---> relu layer:  (?, 16, 16, 32)
#    ---> max pool layer:  (?, 8, 8, 32)
# conv2 layer:  (?, 8, 8, 32)
# flatten layer:  (?, 2048)
# flatten_dropout layer :  (?, 2048)
# fully_connected1 layer:  (?, 1024)
# output layer:  (?, 10)
#
# x:  (?, 32, 32, 3)
# Creating conv2d_maxpool layer
#    ---> conv layer:  (?, 32, 32, 16)
#    ---> relu layer:  (?, 32, 32, 16)
#    ---> max pool layer:  (?, 16, 16, 16)
# conv1 layer:  (?, 16, 16, 16)
# conv1_dropout layer:  (?, 16, 16, 16)
# Creating conv2d_maxpool layer
#    ---> conv layer:  (?, 16, 16, 32)
#    ---> relu layer:  (?, 16, 16, 32)
#    ---> max pool layer:  (?, 8, 8, 32)
# conv2 layer:  (?, 8, 8, 32)
# flatten layer:  (?, 2048)
# flatten_dropout layer :  (?, 2048)
# fully_connected1 layer:  (?, 1024)
# output layer:  (?, 10)
#
# Neural Network Built!

# %%
DEBUG_FLAG_ = False

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict_train = {x: feature_batch, y: label_batch, keep_prob: keep_probability}
    session.run(optimizer, feed_dict=feed_dict_train)
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    val_accuracy = session.run(accuracy, feed_dict={
       x: valid_features,
       y: valid_labels,
       keep_prob: 1.0
    })
    
    loss = session.run(cost, feed_dict={x:feature_batch,
                                       y:label_batch,
                                       keep_prob:1.0})
    
    print('Validation Accuracy at {}'.format(val_accuracy), ' Loss at {}'.format(loss))
                    
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Validation Accuracy at 0.313400000333786  Loss at 2.1324844360351562
# Epoch  2, CIFAR-10 Batch 1:  Validation Accuracy at 0.36079999804496765  Loss at 1.954656958580017
# Epoch  3, CIFAR-10 Batch 1:  Validation Accuracy at 0.39719998836517334  Loss at 1.8585342168807983
# Epoch  4, CIFAR-10 Batch 1:  Validation Accuracy at 0.4408000111579895  Loss at 1.7454893589019775
# Epoch  5, CIFAR-10 Batch 1:  Validation Accuracy at 0.45019999146461487  Loss at 1.7216808795928955
# Epoch  6, CIFAR-10 Batch 1:  Validation Accuracy at 0.48559999465942383  Loss at 1.5373501777648926
# Epoch  7, CIFAR-10 Batch 1:  Validation Accuracy at 0.48739999532699585  Loss at 1.4499788284301758
# Epoch  8, CIFAR-10 Batch 1:  Validation Accuracy at 0.5026000142097473  Loss at 1.3107913732528687
# Epoch  9, CIFAR-10 Batch 1:  Validation Accuracy at 0.5189999938011169  Loss at 1.1658856868743896
# Epoch 10, CIFAR-10 Batch 1:  Validation Accuracy at 0.5249999761581421  Loss at 1.0497279167175293
# Epoch 11, CIFAR-10 Batch 1:  Validation Accuracy at 0.5374000072479248  Loss at 0.9255396723747253
# Epoch 12, CIFAR-10 Batch 1:  Validation Accuracy at 0.5464000105857849  Loss at 0.8424108624458313
# Epoch 13, CIFAR-10 Batch 1:  Validation Accuracy at 0.5598000288009644  Loss at 0.7722095251083374
# Epoch 14, CIFAR-10 Batch 1:  Validation Accuracy at 0.5716000199317932  Loss at 0.6548115015029907
# Epoch 15, CIFAR-10 Batch 1:  Validation Accuracy at 0.5681999921798706  Loss at 0.6212537288665771
# Epoch 16, CIFAR-10 Batch 1:  Validation Accuracy at 0.5812000036239624  Loss at 0.5385026335716248
# Epoch 17, CIFAR-10 Batch 1:  Validation Accuracy at 0.579800009727478  Loss at 0.4622105062007904
# Epoch 18, CIFAR-10 Batch 1:  Validation Accuracy at 0.5879999995231628  Loss at 0.3991186022758484
# Epoch 19, CIFAR-10 Batch 1:  Validation Accuracy at 0.5902000069618225  Loss at 0.3368780314922333
# Epoch 20, CIFAR-10 Batch 1:  Validation Accuracy at 0.5938000082969666  Loss at 0.2677721381187439

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Validation Accuracy at 0.3646000027656555  Loss at 1.9408605098724365
# Epoch  1, CIFAR-10 Batch 2:  Validation Accuracy at 0.4163999855518341  Loss at 1.6727397441864014
# Epoch  1, CIFAR-10 Batch 3:  Validation Accuracy at 0.46059998869895935  Loss at 1.451719045639038
# Epoch  1, CIFAR-10 Batch 4:  Validation Accuracy at 0.4875999987125397  Loss at 1.4656870365142822
# Epoch  1, CIFAR-10 Batch 5:  Validation Accuracy at 0.49160000681877136  Loss at 1.5401136875152588
# Epoch  2, CIFAR-10 Batch 1:  Validation Accuracy at 0.5080000162124634  Loss at 1.6436229944229126
# Epoch  2, CIFAR-10 Batch 2:  Validation Accuracy at 0.5049999952316284  Loss at 1.3321621417999268
# Epoch  2, CIFAR-10 Batch 3:  Validation Accuracy at 0.5296000242233276  Loss at 1.1943330764770508
# Epoch  2, CIFAR-10 Batch 4:  Validation Accuracy at 0.5375999808311462  Loss at 1.25743567943573
# Epoch  2, CIFAR-10 Batch 5:  Validation Accuracy at 0.5540000200271606  Loss at 1.353111982345581
# Epoch  3, CIFAR-10 Batch 1:  Validation Accuracy at 0.5565999746322632  Loss at 1.39311945438385
# Epoch  3, CIFAR-10 Batch 2:  Validation Accuracy at 0.5716000199317932  Loss at 1.1845426559448242
# Epoch  3, CIFAR-10 Batch 3:  Validation Accuracy at 0.5741999745368958  Loss at 1.024470329284668
# Epoch  3, CIFAR-10 Batch 4:  Validation Accuracy at 0.5716000199317932  Loss at 1.1472541093826294
# Epoch  3, CIFAR-10 Batch 5:  Validation Accuracy at 0.5809999704360962  Loss at 1.2119836807250977
# Epoch  4, CIFAR-10 Batch 1:  Validation Accuracy at 0.5985999703407288  Loss at 1.1313310861587524
# Epoch  4, CIFAR-10 Batch 2:  Validation Accuracy at 0.5946000218391418  Loss at 1.1062781810760498
# Epoch  4, CIFAR-10 Batch 3:  Validation Accuracy at 0.5843999981880188  Loss at 0.9717828631401062
# Epoch  4, CIFAR-10 Batch 4:  Validation Accuracy at 0.6140000224113464  Loss at 0.9344438314437866
# Epoch  4, CIFAR-10 Batch 5:  Validation Accuracy at 0.6136000156402588  Loss at 1.0258699655532837
# Epoch  5, CIFAR-10 Batch 1:  Validation Accuracy at 0.621399998664856  Loss at 1.0290822982788086
# Epoch  5, CIFAR-10 Batch 2:  Validation Accuracy at 0.6158000230789185  Loss at 0.9144989848136902
# Epoch  5, CIFAR-10 Batch 3:  Validation Accuracy at 0.6144000291824341  Loss at 0.7837777137756348
# Epoch  5, CIFAR-10 Batch 4:  Validation Accuracy at 0.6363999843597412  Loss at 0.8181113004684448
# Epoch  5, CIFAR-10 Batch 5:  Validation Accuracy at 0.6359999775886536  Loss at 0.8425060510635376
# Epoch  6, CIFAR-10 Batch 1:  Validation Accuracy at 0.6341999769210815  Loss at 0.9053090214729309
# Epoch  6, CIFAR-10 Batch 2:  Validation Accuracy at 0.6425999999046326  Loss at 0.8030945062637329
# Epoch  6, CIFAR-10 Batch 3:  Validation Accuracy at 0.646399974822998  Loss at 0.6769672632217407
# Epoch  6, CIFAR-10 Batch 4:  Validation Accuracy at 0.6539999842643738  Loss at 0.7214061617851257
# Epoch  6, CIFAR-10 Batch 5:  Validation Accuracy at 0.6565999984741211  Loss at 0.726729154586792
# Epoch  7, CIFAR-10 Batch 1:  Validation Accuracy at 0.6549999713897705  Loss at 0.7667981386184692
# Epoch  7, CIFAR-10 Batch 2:  Validation Accuracy at 0.6615999937057495  Loss at 0.7240394353866577
# Epoch  7, CIFAR-10 Batch 3:  Validation Accuracy at 0.6565999984741211  Loss at 0.5937608480453491
# Epoch  7, CIFAR-10 Batch 4:  Validation Accuracy at 0.6692000031471252  Loss at 0.6108121275901794
# Epoch  7, CIFAR-10 Batch 5:  Validation Accuracy at 0.675599992275238  Loss at 0.6229726076126099
# Epoch  8, CIFAR-10 Batch 1:  Validation Accuracy at 0.6740000247955322  Loss at 0.66865074634552
# Epoch  8, CIFAR-10 Batch 2:  Validation Accuracy at 0.6741999983787537  Loss at 0.624047577381134
# Epoch  8, CIFAR-10 Batch 3:  Validation Accuracy at 0.6692000031471252  Loss at 0.4794108271598816
# Epoch  8, CIFAR-10 Batch 4:  Validation Accuracy at 0.6808000206947327  Loss at 0.5208778381347656
# Epoch  8, CIFAR-10 Batch 5:  Validation Accuracy at 0.6848000288009644  Loss at 0.5107841491699219
# Epoch  9, CIFAR-10 Batch 1:  Validation Accuracy at 0.6812000274658203  Loss at 0.5674858689308167
# Epoch  9, CIFAR-10 Batch 2:  Validation Accuracy at 0.682200014591217  Loss at 0.5496231913566589
# Epoch  9, CIFAR-10 Batch 3:  Validation Accuracy at 0.6782000064849854  Loss at 0.432424396276474
# Epoch  9, CIFAR-10 Batch 4:  Validation Accuracy at 0.6912000179290771  Loss at 0.5057195425033569
# Epoch  9, CIFAR-10 Batch 5:  Validation Accuracy at 0.694599986076355  Loss at 0.47953224182128906
# Epoch 10, CIFAR-10 Batch 1:  Validation Accuracy at 0.6913999915122986  Loss at 0.4908013939857483
# Epoch 10, CIFAR-10 Batch 2:  Validation Accuracy at 0.6814000010490417  Loss at 0.5261436700820923
# Epoch 10, CIFAR-10 Batch 3:  Validation Accuracy at 0.6862000226974487  Loss at 0.3515273332595825
# Epoch 10, CIFAR-10 Batch 4:  Validation Accuracy at 0.6809999942779541  Loss at 0.47692757844924927
# Epoch 10, CIFAR-10 Batch 5:  Validation Accuracy at 0.7006000280380249  Loss at 0.38932156562805176
# Epoch 11, CIFAR-10 Batch 1:  Validation Accuracy at 0.6967999935150146  Loss at 0.45818883180618286
# Epoch 11, CIFAR-10 Batch 2:  Validation Accuracy at 0.6976000070571899  Loss at 0.3777006268501282
# Epoch 11, CIFAR-10 Batch 3:  Validation Accuracy at 0.7157999873161316  Loss at 0.33487850427627563
# Epoch 11, CIFAR-10 Batch 4:  Validation Accuracy at 0.7135999798774719  Loss at 0.3526315689086914
# Epoch 11, CIFAR-10 Batch 5:  Validation Accuracy at 0.7128000259399414  Loss at 0.33175376057624817
# Epoch 12, CIFAR-10 Batch 1:  Validation Accuracy at 0.7081999778747559  Loss at 0.3577062487602234
# Epoch 12, CIFAR-10 Batch 2:  Validation Accuracy at 0.6959999799728394  Loss at 0.3517022430896759
# Epoch 12, CIFAR-10 Batch 3:  Validation Accuracy at 0.7017999887466431  Loss at 0.3063577711582184
# Epoch 12, CIFAR-10 Batch 4:  Validation Accuracy at 0.7178000211715698  Loss at 0.2901284098625183
# Epoch 12, CIFAR-10 Batch 5:  Validation Accuracy at 0.72079998254776  Loss at 0.33781057596206665
# Epoch 13, CIFAR-10 Batch 1:  Validation Accuracy at 0.7224000096321106  Loss at 0.3114052712917328
# Epoch 13, CIFAR-10 Batch 2:  Validation Accuracy at 0.6990000009536743  Loss at 0.3164500594139099
# Epoch 13, CIFAR-10 Batch 3:  Validation Accuracy at 0.7156000137329102  Loss at 0.23621995747089386
# Epoch 13, CIFAR-10 Batch 4:  Validation Accuracy at 0.7098000049591064  Loss at 0.25351864099502563
# Epoch 13, CIFAR-10 Batch 5:  Validation Accuracy at 0.7214000225067139  Loss at 0.25065022706985474
# Epoch 14, CIFAR-10 Batch 1:  Validation Accuracy at 0.722000002861023  Loss at 0.2460733950138092
# Epoch 14, CIFAR-10 Batch 2:  Validation Accuracy at 0.7095999717712402  Loss at 0.21261921525001526
# Epoch 14, CIFAR-10 Batch 3:  Validation Accuracy at 0.7031999826431274  Loss at 0.2116928994655609
# Epoch 14, CIFAR-10 Batch 4:  Validation Accuracy at 0.7178000211715698  Loss at 0.21347780525684357
# Epoch 14, CIFAR-10 Batch 5:  Validation Accuracy at 0.7143999934196472  Loss at 0.2685309052467346
# Epoch 15, CIFAR-10 Batch 1:  Validation Accuracy at 0.7289999723434448  Loss at 0.2226393222808838
# Epoch 15, CIFAR-10 Batch 2:  Validation Accuracy at 0.7235999703407288  Loss at 0.16102321445941925
# Epoch 15, CIFAR-10 Batch 3:  Validation Accuracy at 0.7174000144004822  Loss at 0.1559334248304367
# Epoch 15, CIFAR-10 Batch 4:  Validation Accuracy at 0.7148000001907349  Loss at 0.1829712837934494
# Epoch 15, CIFAR-10 Batch 5:  Validation Accuracy at 0.7178000211715698  Loss at 0.2056460678577423
# Epoch 16, CIFAR-10 Batch 1:  Validation Accuracy at 0.7265999913215637  Loss at 0.2192453145980835
# Epoch 16, CIFAR-10 Batch 2:  Validation Accuracy at 0.7178000211715698  Loss at 0.137217715382576
# Epoch 16, CIFAR-10 Batch 3:  Validation Accuracy at 0.7006000280380249  Loss at 0.12741217017173767
# Epoch 16, CIFAR-10 Batch 4:  Validation Accuracy at 0.722599983215332  Loss at 0.14201167225837708
# Epoch 16, CIFAR-10 Batch 5:  Validation Accuracy at 0.7221999764442444  Loss at 0.14034606516361237
# Epoch 17, CIFAR-10 Batch 1:  Validation Accuracy at 0.7275999784469604  Loss at 0.16896037757396698
# Epoch 17, CIFAR-10 Batch 2:  Validation Accuracy at 0.7157999873161316  Loss at 0.10129402577877045
# Epoch 17, CIFAR-10 Batch 3:  Validation Accuracy at 0.7210000157356262  Loss at 0.12173283100128174
# Epoch 17, CIFAR-10 Batch 4:  Validation Accuracy at 0.7278000116348267  Loss at 0.11195290088653564
# Epoch 17, CIFAR-10 Batch 5:  Validation Accuracy at 0.727400004863739  Loss at 0.1086445078253746
# Epoch 18, CIFAR-10 Batch 1:  Validation Accuracy at 0.7350000143051147  Loss at 0.10888143628835678
# Epoch 18, CIFAR-10 Batch 2:  Validation Accuracy at 0.7143999934196472  Loss at 0.09773285686969757
# Epoch 18, CIFAR-10 Batch 3:  Validation Accuracy at 0.7247999906539917  Loss at 0.10350712388753891
# Epoch 18, CIFAR-10 Batch 4:  Validation Accuracy at 0.727400004863739  Loss at 0.11543633788824081
# Epoch 18, CIFAR-10 Batch 5:  Validation Accuracy at 0.7278000116348267  Loss at 0.09713973104953766
# Epoch 19, CIFAR-10 Batch 1:  Validation Accuracy at 0.7246000170707703  Loss at 0.122341588139534
# Epoch 19, CIFAR-10 Batch 2:  Validation Accuracy at 0.723800003528595  Loss at 0.07986826449632645
# Epoch 19, CIFAR-10 Batch 3:  Validation Accuracy at 0.7129999995231628  Loss at 0.1019475907087326
# Epoch 19, CIFAR-10 Batch 4:  Validation Accuracy at 0.7149999737739563  Loss at 0.10047794878482819
# Epoch 19, CIFAR-10 Batch 5:  Validation Accuracy at 0.7329999804496765  Loss at 0.08812158554792404
# Epoch 20, CIFAR-10 Batch 1:  Validation Accuracy at 0.7324000000953674  Loss at 0.10551335662603378
# Epoch 20, CIFAR-10 Batch 2:  Validation Accuracy at 0.728600025177002  Loss at 0.09881004691123962
# Epoch 20, CIFAR-10 Batch 3:  Validation Accuracy at 0.7250000238418579  Loss at 0.0787665992975235
# Epoch 20, CIFAR-10 Batch 4:  Validation Accuracy at 0.7184000015258789  Loss at 0.08722081035375595
# Epoch 20, CIFAR-10 Batch 5:  Validation Accuracy at 0.718999981880188  Loss at 0.06805821508169174
# Epoch 21, CIFAR-10 Batch 1:  Validation Accuracy at 0.7337999939918518  Loss at 0.07090972363948822
# Epoch 21, CIFAR-10 Batch 2:  Validation Accuracy at 0.7221999764442444  Loss at 0.11400707066059113
# Epoch 21, CIFAR-10 Batch 3:  Validation Accuracy at 0.7265999913215637  Loss at 0.07774744927883148
# Epoch 21, CIFAR-10 Batch 4:  Validation Accuracy at 0.7134000062942505  Loss at 0.07140382379293442
# Epoch 21, CIFAR-10 Batch 5:  Validation Accuracy at 0.729200005531311  Loss at 0.05641363933682442
# Epoch 22, CIFAR-10 Batch 1:  Validation Accuracy at 0.7310000061988831  Loss at 0.09937556087970734
# Epoch 22, CIFAR-10 Batch 2:  Validation Accuracy at 0.7221999764442444  Loss at 0.09566227346658707
# Epoch 22, CIFAR-10 Batch 3:  Validation Accuracy at 0.7251999974250793  Loss at 0.04888510704040527
# Epoch 22, CIFAR-10 Batch 4:  Validation Accuracy at 0.7192000150680542  Loss at 0.07595367729663849
# Epoch 22, CIFAR-10 Batch 5:  Validation Accuracy at 0.7332000136375427  Loss at 0.05551154538989067
# Epoch 23, CIFAR-10 Batch 1:  Validation Accuracy at 0.7275999784469604  Loss at 0.0741487368941307
# Epoch 23, CIFAR-10 Batch 2:  Validation Accuracy at 0.7224000096321106  Loss at 0.09135590493679047
# Epoch 23, CIFAR-10 Batch 3:  Validation Accuracy at 0.7269999980926514  Loss at 0.06743188202381134
# Epoch 23, CIFAR-10 Batch 4:  Validation Accuracy at 0.718999981880188  Loss at 0.07067038118839264
# Epoch 23, CIFAR-10 Batch 5:  Validation Accuracy at 0.7224000096321106  Loss at 0.04529071971774101
# Epoch 24, CIFAR-10 Batch 1:  Validation Accuracy at 0.7355999946594238  Loss at 0.052599381655454636
# Epoch 24, CIFAR-10 Batch 2:  Validation Accuracy at 0.7264000177383423  Loss at 0.05723446607589722
# Epoch 24, CIFAR-10 Batch 3:  Validation Accuracy at 0.7279999852180481  Loss at 0.037736691534519196
# Epoch 24, CIFAR-10 Batch 4:  Validation Accuracy at 0.7318000197410583  Loss at 0.045017633587121964
# Epoch 24, CIFAR-10 Batch 5:  Validation Accuracy at 0.7250000238418579  Loss at 0.046037234365940094
# Epoch 25, CIFAR-10 Batch 1:  Validation Accuracy at 0.7261999845504761  Loss at 0.06575269997119904
# Epoch 25, CIFAR-10 Batch 2:  Validation Accuracy at 0.717199981212616  Loss at 0.055375732481479645
# Epoch 25, CIFAR-10 Batch 3:  Validation Accuracy at 0.7246000170707703  Loss at 0.04936041682958603
# Epoch 25, CIFAR-10 Batch 4:  Validation Accuracy at 0.7253999710083008  Loss at 0.04200416058301926
# Epoch 25, CIFAR-10 Batch 5:  Validation Accuracy at 0.7265999913215637  Loss at 0.0341266505420208
# Epoch 26, CIFAR-10 Batch 1:  Validation Accuracy at 0.7315999865531921  Loss at 0.02780960127711296
# Epoch 26, CIFAR-10 Batch 2:  Validation Accuracy at 0.7197999954223633  Loss at 0.0439535453915596
# Epoch 26, CIFAR-10 Batch 3:  Validation Accuracy at 0.7224000096321106  Loss at 0.04159199446439743
# Epoch 26, CIFAR-10 Batch 4:  Validation Accuracy at 0.7247999906539917  Loss at 0.046027712523937225
# Epoch 26, CIFAR-10 Batch 5:  Validation Accuracy at 0.7333999872207642  Loss at 0.03367266803979874
# Epoch 27, CIFAR-10 Batch 1:  Validation Accuracy at 0.729200005531311  Loss at 0.026952365413308144
# Epoch 27, CIFAR-10 Batch 2:  Validation Accuracy at 0.7239999771118164  Loss at 0.05949343368411064
# Epoch 27, CIFAR-10 Batch 3:  Validation Accuracy at 0.7305999994277954  Loss at 0.039224762469530106
# Epoch 27, CIFAR-10 Batch 4:  Validation Accuracy at 0.72079998254776  Loss at 0.04512937366962433
# Epoch 27, CIFAR-10 Batch 5:  Validation Accuracy at 0.7287999987602234  Loss at 0.0348980538547039
# Epoch 28, CIFAR-10 Batch 1:  Validation Accuracy at 0.7242000102996826  Loss at 0.03711976483464241
# Epoch 28, CIFAR-10 Batch 2:  Validation Accuracy at 0.7184000015258789  Loss at 0.029767891392111778
# Epoch 28, CIFAR-10 Batch 3:  Validation Accuracy at 0.7185999751091003  Loss at 0.0254023727029562
# Epoch 28, CIFAR-10 Batch 4:  Validation Accuracy at 0.723800003528595  Loss at 0.02741869166493416
# Epoch 28, CIFAR-10 Batch 5:  Validation Accuracy at 0.7300000190734863  Loss at 0.02673867903649807
# Epoch 29, CIFAR-10 Batch 1:  Validation Accuracy at 0.7211999893188477  Loss at 0.04159221798181534
# Epoch 29, CIFAR-10 Batch 2:  Validation Accuracy at 0.7174000144004822  Loss at 0.029708880931138992
# Epoch 29, CIFAR-10 Batch 3:  Validation Accuracy at 0.7269999980926514  Loss at 0.027824407443404198
# Epoch 29, CIFAR-10 Batch 4:  Validation Accuracy at 0.7287999987602234  Loss at 0.027470070868730545
# Epoch 29, CIFAR-10 Batch 5:  Validation Accuracy at 0.7296000123023987  Loss at 0.02532842755317688
# Epoch 30, CIFAR-10 Batch 1:  Validation Accuracy at 0.7350000143051147  Loss at 0.02611854299902916
# Epoch 30, CIFAR-10 Batch 2:  Validation Accuracy at 0.7214000225067139  Loss at 0.030803173780441284
# Epoch 30, CIFAR-10 Batch 3:  Validation Accuracy at 0.7146000266075134  Loss at 0.035807494074106216
# Epoch 30, CIFAR-10 Batch 4:  Validation Accuracy at 0.7235999703407288  Loss at 0.03771331161260605
# Epoch 30, CIFAR-10 Batch 5:  Validation Accuracy at 0.7242000102996826  Loss at 0.0197741836309433
# Epoch 31, CIFAR-10 Batch 1:  Validation Accuracy at 0.7296000123023987  Loss at 0.023177001625299454
# Epoch 31, CIFAR-10 Batch 2:  Validation Accuracy at 0.7179999947547913  Loss at 0.031413301825523376
# Epoch 31, CIFAR-10 Batch 3:  Validation Accuracy at 0.7193999886512756  Loss at 0.022551529109477997
# Epoch 31, CIFAR-10 Batch 4:  Validation Accuracy at 0.7283999919891357  Loss at 0.020911045372486115
# Epoch 31, CIFAR-10 Batch 5:  Validation Accuracy at 0.7296000123023987  Loss at 0.019163021817803383
# Epoch 32, CIFAR-10 Batch 1:  Validation Accuracy at 0.7257999777793884  Loss at 0.024309460073709488
# Epoch 32, CIFAR-10 Batch 2:  Validation Accuracy at 0.7146000266075134  Loss at 0.05335549637675285
# Epoch 32, CIFAR-10 Batch 3:  Validation Accuracy at 0.7197999954223633  Loss at 0.015351662412285805
# Epoch 32, CIFAR-10 Batch 4:  Validation Accuracy at 0.7148000001907349  Loss at 0.027530765160918236
# Epoch 32, CIFAR-10 Batch 5:  Validation Accuracy at 0.7200000286102295  Loss at 0.019234374165534973
# Epoch 33, CIFAR-10 Batch 1:  Validation Accuracy at 0.7221999764442444  Loss at 0.029601478949189186
# Epoch 33, CIFAR-10 Batch 2:  Validation Accuracy at 0.7271999716758728  Loss at 0.022479629144072533
# Epoch 33, CIFAR-10 Batch 3:  Validation Accuracy at 0.7202000021934509  Loss at 0.022229276597499847
# Epoch 33, CIFAR-10 Batch 4:  Validation Accuracy at 0.7260000109672546  Loss at 0.03190571814775467
# Epoch 33, CIFAR-10 Batch 5:  Validation Accuracy at 0.7307999730110168  Loss at 0.017831722274422646
# Epoch 34, CIFAR-10 Batch 1:  Validation Accuracy at 0.734000027179718  Loss at 0.01576336659491062
# Epoch 34, CIFAR-10 Batch 2:  Validation Accuracy at 0.7235999703407288  Loss at 0.0284039918333292
# Epoch 34, CIFAR-10 Batch 3:  Validation Accuracy at 0.728600025177002  Loss at 0.02038475312292576
# Epoch 34, CIFAR-10 Batch 4:  Validation Accuracy at 0.7242000102996826  Loss at 0.021266525611281395
# Epoch 34, CIFAR-10 Batch 5:  Validation Accuracy at 0.7135999798774719  Loss at 0.022501999512314796
# Epoch 35, CIFAR-10 Batch 1:  Validation Accuracy at 0.7214000225067139  Loss at 0.020480036735534668
# Epoch 35, CIFAR-10 Batch 2:  Validation Accuracy at 0.7107999920845032  Loss at 0.026349002495408058
# Epoch 35, CIFAR-10 Batch 3:  Validation Accuracy at 0.7128000259399414  Loss at 0.012178661301732063
# Epoch 35, CIFAR-10 Batch 4:  Validation Accuracy at 0.723800003528595  Loss at 0.017371082678437233
# Epoch 35, CIFAR-10 Batch 5:  Validation Accuracy at 0.7228000164031982  Loss at 0.03067728504538536
# Epoch 36, CIFAR-10 Batch 1:  Validation Accuracy at 0.7224000096321106  Loss at 0.022268135100603104
# Epoch 36, CIFAR-10 Batch 2:  Validation Accuracy at 0.7228000164031982  Loss at 0.02416140027344227
# Epoch 36, CIFAR-10 Batch 3:  Validation Accuracy at 0.7246000170707703  Loss at 0.008191079832613468
# Epoch 36, CIFAR-10 Batch 4:  Validation Accuracy at 0.723800003528595  Loss at 0.011076273396611214
# Epoch 36, CIFAR-10 Batch 5:  Validation Accuracy at 0.7271999716758728  Loss at 0.014767018146812916
# Epoch 37, CIFAR-10 Batch 1:  Validation Accuracy at 0.7293999791145325  Loss at 0.013772107660770416
# Epoch 37, CIFAR-10 Batch 2:  Validation Accuracy at 0.7192000150680542  Loss at 0.015102711506187916
# Epoch 37, CIFAR-10 Batch 3:  Validation Accuracy at 0.7232000231742859  Loss at 0.0196561086922884
# Epoch 37, CIFAR-10 Batch 4:  Validation Accuracy at 0.7275999784469604  Loss at 0.01388357300311327
# Epoch 37, CIFAR-10 Batch 5:  Validation Accuracy at 0.7185999751091003  Loss at 0.01204516738653183
# Epoch 38, CIFAR-10 Batch 1:  Validation Accuracy at 0.7149999737739563  Loss at 0.02082950808107853
# Epoch 38, CIFAR-10 Batch 2:  Validation Accuracy at 0.724399983882904  Loss at 0.01520337350666523
# Epoch 38, CIFAR-10 Batch 3:  Validation Accuracy at 0.7354000210762024  Loss at 0.015129340812563896
# Epoch 38, CIFAR-10 Batch 4:  Validation Accuracy at 0.7250000238418579  Loss at 0.02279891073703766
# Epoch 38, CIFAR-10 Batch 5:  Validation Accuracy at 0.728600025177002  Loss at 0.028062179684638977
# Epoch 39, CIFAR-10 Batch 1:  Validation Accuracy at 0.7376000285148621  Loss at 0.021711692214012146
# Epoch 39, CIFAR-10 Batch 2:  Validation Accuracy at 0.7193999886512756  Loss at 0.016698528081178665
# Epoch 39, CIFAR-10 Batch 3:  Validation Accuracy at 0.7347999811172485  Loss at 0.014986669644713402
# Epoch 39, CIFAR-10 Batch 4:  Validation Accuracy at 0.7279999852180481  Loss at 0.013032478280365467
# Epoch 39, CIFAR-10 Batch 5:  Validation Accuracy at 0.7265999913215637  Loss at 0.018609803169965744
# Epoch 40, CIFAR-10 Batch 1:  Validation Accuracy at 0.7202000021934509  Loss at 0.03164861723780632
# Epoch 40, CIFAR-10 Batch 2:  Validation Accuracy at 0.7265999913215637  Loss at 0.01873067021369934
# Epoch 40, CIFAR-10 Batch 3:  Validation Accuracy at 0.7325999736785889  Loss at 0.013899284414947033
# Epoch 40, CIFAR-10 Batch 4:  Validation Accuracy at 0.7355999946594238  Loss at 0.02532653883099556
# Epoch 40, CIFAR-10 Batch 5:  Validation Accuracy at 0.7228000164031982  Loss at 0.011749598197638988
# Epoch 41, CIFAR-10 Batch 1:  Validation Accuracy at 0.7283999919891357  Loss at 0.01238547544926405
# Epoch 41, CIFAR-10 Batch 2:  Validation Accuracy at 0.7253999710083008  Loss at 0.016089007258415222
# Epoch 41, CIFAR-10 Batch 3:  Validation Accuracy at 0.728600025177002  Loss at 0.009232793934643269
# Epoch 41, CIFAR-10 Batch 4:  Validation Accuracy at 0.7342000007629395  Loss at 0.013759417459368706
# Epoch 41, CIFAR-10 Batch 5:  Validation Accuracy at 0.7250000238418579  Loss at 0.006324201822280884
# Epoch 42, CIFAR-10 Batch 1:  Validation Accuracy at 0.7287999987602234  Loss at 0.010501575656235218
# Epoch 42, CIFAR-10 Batch 2:  Validation Accuracy at 0.7196000218391418  Loss at 0.01780082657933235
# Epoch 42, CIFAR-10 Batch 3:  Validation Accuracy at 0.7283999919891357  Loss at 0.010280266404151917
# Epoch 42, CIFAR-10 Batch 4:  Validation Accuracy at 0.734000027179718  Loss at 0.010036994703114033
# Epoch 42, CIFAR-10 Batch 5:  Validation Accuracy at 0.7264000177383423  Loss at 0.009225575253367424
# Epoch 43, CIFAR-10 Batch 1:  Validation Accuracy at 0.7265999913215637  Loss at 0.015039021149277687
# Epoch 43, CIFAR-10 Batch 2:  Validation Accuracy at 0.7253999710083008  Loss at 0.015240451321005821
# Epoch 43, CIFAR-10 Batch 3:  Validation Accuracy at 0.729200005531311  Loss at 0.007687924895435572
# Epoch 43, CIFAR-10 Batch 4:  Validation Accuracy at 0.7265999913215637  Loss at 0.010388178750872612
# Epoch 43, CIFAR-10 Batch 5:  Validation Accuracy at 0.7265999913215637  Loss at 0.015494066290557384
# Epoch 44, CIFAR-10 Batch 1:  Validation Accuracy at 0.7232000231742859  Loss at 0.008369624614715576
# Epoch 44, CIFAR-10 Batch 2:  Validation Accuracy at 0.7214000225067139  Loss at 0.011660286225378513
# Epoch 44, CIFAR-10 Batch 3:  Validation Accuracy at 0.7361999750137329  Loss at 0.0077572353184223175
# Epoch 44, CIFAR-10 Batch 4:  Validation Accuracy at 0.7282000184059143  Loss at 0.00784524716436863
# Epoch 44, CIFAR-10 Batch 5:  Validation Accuracy at 0.7242000102996826  Loss at 0.027162376791238785
# Epoch 45, CIFAR-10 Batch 1:  Validation Accuracy at 0.7293999791145325  Loss at 0.00835169292986393
# Epoch 45, CIFAR-10 Batch 2:  Validation Accuracy at 0.723800003528595  Loss at 0.008578024804592133
# Epoch 45, CIFAR-10 Batch 3:  Validation Accuracy at 0.7239999771118164  Loss at 0.006477834191173315
# Epoch 45, CIFAR-10 Batch 4:  Validation Accuracy at 0.7275999784469604  Loss at 0.021318215876817703
# Epoch 45, CIFAR-10 Batch 5:  Validation Accuracy at 0.7214000225067139  Loss at 0.010554778389632702
# Epoch 46, CIFAR-10 Batch 1:  Validation Accuracy at 0.7325999736785889  Loss at 0.022132251411676407
# Epoch 46, CIFAR-10 Batch 2:  Validation Accuracy at 0.7242000102996826  Loss at 0.008586938492953777
# Epoch 46, CIFAR-10 Batch 3:  Validation Accuracy at 0.7337999939918518  Loss at 0.006087909452617168
# Epoch 46, CIFAR-10 Batch 4:  Validation Accuracy at 0.7396000027656555  Loss at 0.009718544781208038
# Epoch 46, CIFAR-10 Batch 5:  Validation Accuracy at 0.7328000068664551  Loss at 0.007622680626809597
# Epoch 47, CIFAR-10 Batch 1:  Validation Accuracy at 0.7246000170707703  Loss at 0.011252328753471375
# Epoch 47, CIFAR-10 Batch 2:  Validation Accuracy at 0.7260000109672546  Loss at 0.0045372298918664455
# Epoch 47, CIFAR-10 Batch 3:  Validation Accuracy at 0.7269999980926514  Loss at 0.010340152308344841
# Epoch 47, CIFAR-10 Batch 4:  Validation Accuracy at 0.7325999736785889  Loss at 0.016205718740820885
# Epoch 47, CIFAR-10 Batch 5:  Validation Accuracy at 0.730400025844574  Loss at 0.025441974401474
# Epoch 48, CIFAR-10 Batch 1:  Validation Accuracy at 0.7328000068664551  Loss at 0.011252308264374733
# Epoch 48, CIFAR-10 Batch 2:  Validation Accuracy at 0.722000002861023  Loss at 0.004275193437933922
# Epoch 48, CIFAR-10 Batch 3:  Validation Accuracy at 0.7350000143051147  Loss at 0.008838986977934837
# Epoch 48, CIFAR-10 Batch 4:  Validation Accuracy at 0.7419999837875366  Loss at 0.011108040809631348
# Epoch 48, CIFAR-10 Batch 5:  Validation Accuracy at 0.7336000204086304  Loss at 0.009533842094242573
# Epoch 49, CIFAR-10 Batch 1:  Validation Accuracy at 0.7297999858856201  Loss at 0.00730914156883955
# Epoch 49, CIFAR-10 Batch 2:  Validation Accuracy at 0.7279999852180481  Loss at 0.00462119048461318
# Epoch 49, CIFAR-10 Batch 3:  Validation Accuracy at 0.7373999953269958  Loss at 0.00642993301153183
# Epoch 49, CIFAR-10 Batch 4:  Validation Accuracy at 0.732200026512146  Loss at 0.012882995419204235
# Epoch 49, CIFAR-10 Batch 5:  Validation Accuracy at 0.730400025844574  Loss at 0.004383842460811138
# Epoch 50, CIFAR-10 Batch 1:  Validation Accuracy at 0.7297999858856201  Loss at 0.012104922905564308
# Epoch 50, CIFAR-10 Batch 2:  Validation Accuracy at 0.7203999757766724  Loss at 0.007744782604277134
# Epoch 50, CIFAR-10 Batch 3:  Validation Accuracy at 0.722599983215332  Loss at 0.0054589868523180485
# Epoch 50, CIFAR-10 Batch 4:  Validation Accuracy at 0.7253999710083008  Loss at 0.006973118521273136
# Epoch 50, CIFAR-10 Batch 5:  Validation Accuracy at 0.7250000238418579  Loss at 0.013281168416142464
# Epoch 51, CIFAR-10 Batch 1:  Validation Accuracy at 0.72079998254776  Loss at 0.0061914087273180485
# Epoch 51, CIFAR-10 Batch 2:  Validation Accuracy at 0.7265999913215637  Loss at 0.0053538489155471325
# Epoch 51, CIFAR-10 Batch 3:  Validation Accuracy at 0.7206000089645386  Loss at 0.006667472422122955
# Epoch 51, CIFAR-10 Batch 4:  Validation Accuracy at 0.7283999919891357  Loss at 0.00736700976267457
# Epoch 51, CIFAR-10 Batch 5:  Validation Accuracy at 0.7265999913215637  Loss at 0.012837055139243603
# Epoch 52, CIFAR-10 Batch 1:  Validation Accuracy at 0.7387999892234802  Loss at 0.003090459853410721
# Epoch 52, CIFAR-10 Batch 2:  Validation Accuracy at 0.7242000102996826  Loss at 0.0023767207749187946
# Epoch 52, CIFAR-10 Batch 3:  Validation Accuracy at 0.7233999967575073  Loss at 0.009222084656357765
# Epoch 52, CIFAR-10 Batch 4:  Validation Accuracy at 0.734000027179718  Loss at 0.011748941615223885
# Epoch 52, CIFAR-10 Batch 5:  Validation Accuracy at 0.7319999933242798  Loss at 0.020120855420827866
# Epoch 53, CIFAR-10 Batch 1:  Validation Accuracy at 0.7329999804496765  Loss at 0.005871193949133158
# Epoch 53, CIFAR-10 Batch 2:  Validation Accuracy at 0.7214000225067139  Loss at 0.0064031826332211494
# Epoch 53, CIFAR-10 Batch 3:  Validation Accuracy at 0.7278000116348267  Loss at 0.004936409182846546
# Epoch 53, CIFAR-10 Batch 4:  Validation Accuracy at 0.7364000082015991  Loss at 0.010688284412026405
# Epoch 53, CIFAR-10 Batch 5:  Validation Accuracy at 0.727400004863739  Loss at 0.009304729290306568
# Epoch 54, CIFAR-10 Batch 1:  Validation Accuracy at 0.7250000238418579  Loss at 0.004845290444791317
# Epoch 54, CIFAR-10 Batch 2:  Validation Accuracy at 0.725600004196167  Loss at 0.007387714926153421
# Epoch 54, CIFAR-10 Batch 3:  Validation Accuracy at 0.7197999954223633  Loss at 0.01564663089811802
# Epoch 54, CIFAR-10 Batch 4:  Validation Accuracy at 0.7170000076293945  Loss at 0.010791033506393433
# Epoch 54, CIFAR-10 Batch 5:  Validation Accuracy at 0.7319999933242798  Loss at 0.004065735265612602
# Epoch 55, CIFAR-10 Batch 1:  Validation Accuracy at 0.7325999736785889  Loss at 0.012237909249961376
# Epoch 55, CIFAR-10 Batch 2:  Validation Accuracy at 0.7229999899864197  Loss at 0.006741862744092941
# Epoch 55, CIFAR-10 Batch 3:  Validation Accuracy at 0.7372000217437744  Loss at 0.005731066223233938
# Epoch 55, CIFAR-10 Batch 4:  Validation Accuracy at 0.7346000075340271  Loss at 0.01711069419980049
# Epoch 55, CIFAR-10 Batch 5:  Validation Accuracy at 0.7283999919891357  Loss at 0.00521888118237257
# Epoch 56, CIFAR-10 Batch 1:  Validation Accuracy at 0.7324000000953674  Loss at 0.00436745397746563
# Epoch 56, CIFAR-10 Batch 2:  Validation Accuracy at 0.7301999926567078  Loss at 0.004027512390166521
# Epoch 56, CIFAR-10 Batch 3:  Validation Accuracy at 0.7282000184059143  Loss at 0.004651402123272419
# Epoch 56, CIFAR-10 Batch 4:  Validation Accuracy at 0.7324000000953674  Loss at 0.004018039908260107
# Epoch 56, CIFAR-10 Batch 5:  Validation Accuracy at 0.7283999919891357  Loss at 0.003727125469595194
# Epoch 57, CIFAR-10 Batch 1:  Validation Accuracy at 0.7342000007629395  Loss at 0.00444821547716856
# Epoch 57, CIFAR-10 Batch 2:  Validation Accuracy at 0.7203999757766724  Loss at 0.003966351039707661
# Epoch 57, CIFAR-10 Batch 3:  Validation Accuracy at 0.727400004863739  Loss at 0.005089791491627693
# Epoch 57, CIFAR-10 Batch 4:  Validation Accuracy at 0.7192000150680542  Loss at 0.00566419493407011
# Epoch 57, CIFAR-10 Batch 5:  Validation Accuracy at 0.7283999919891357  Loss at 0.0030646473169326782
# Epoch 58, CIFAR-10 Batch 1:  Validation Accuracy at 0.7305999994277954  Loss at 0.003276997013017535
# Epoch 58, CIFAR-10 Batch 2:  Validation Accuracy at 0.7301999926567078  Loss at 0.004058432299643755
# Epoch 58, CIFAR-10 Batch 3:  Validation Accuracy at 0.7289999723434448  Loss at 0.002661464037373662
# Epoch 58, CIFAR-10 Batch 4:  Validation Accuracy at 0.7257999777793884  Loss at 0.011846895329654217
# Epoch 58, CIFAR-10 Batch 5:  Validation Accuracy at 0.7314000129699707  Loss at 0.006352465599775314
# Epoch 59, CIFAR-10 Batch 1:  Validation Accuracy at 0.7250000238418579  Loss at 0.0025166431441903114
# Epoch 59, CIFAR-10 Batch 2:  Validation Accuracy at 0.7247999906539917  Loss at 0.004601769614964724
# Epoch 59, CIFAR-10 Batch 3:  Validation Accuracy at 0.7337999939918518  Loss at 0.004106664564460516
# Epoch 59, CIFAR-10 Batch 4:  Validation Accuracy at 0.7332000136375427  Loss at 0.011110651306807995
# Epoch 59, CIFAR-10 Batch 5:  Validation Accuracy at 0.732200026512146  Loss at 0.0058191800490021706
# Epoch 60, CIFAR-10 Batch 1:  Validation Accuracy at 0.7264000177383423  Loss at 0.002349189482629299
# Epoch 60, CIFAR-10 Batch 2:  Validation Accuracy at 0.7229999899864197  Loss at 0.00613187113776803
# Epoch 60, CIFAR-10 Batch 3:  Validation Accuracy at 0.7197999954223633  Loss at 0.007751655764877796
# Epoch 60, CIFAR-10 Batch 4:  Validation Accuracy at 0.7271999716758728  Loss at 0.014001792296767235
# Epoch 60, CIFAR-10 Batch 5:  Validation Accuracy at 0.722599983215332  Loss at 0.003135656239464879
# Epoch 61, CIFAR-10 Batch 1:  Validation Accuracy at 0.7278000116348267  Loss at 0.0022860239259898663
# Epoch 61, CIFAR-10 Batch 2:  Validation Accuracy at 0.729200005531311  Loss at 0.0023891907185316086
# Epoch 61, CIFAR-10 Batch 3:  Validation Accuracy at 0.7282000184059143  Loss at 0.004253121558576822
# Epoch 61, CIFAR-10 Batch 4:  Validation Accuracy at 0.7346000075340271  Loss at 0.0040686228312551975
# Epoch 61, CIFAR-10 Batch 5:  Validation Accuracy at 0.7271999716758728  Loss at 0.0033133707474917173
# Epoch 62, CIFAR-10 Batch 1:  Validation Accuracy at 0.7232000231742859  Loss at 0.0035839404445141554
# Epoch 62, CIFAR-10 Batch 2:  Validation Accuracy at 0.7282000184059143  Loss at 0.0015206453390419483
# Epoch 62, CIFAR-10 Batch 3:  Validation Accuracy at 0.7239999771118164  Loss at 0.003671635640785098
# Epoch 62, CIFAR-10 Batch 4:  Validation Accuracy at 0.7271999716758728  Loss at 0.005204370245337486
# Epoch 62, CIFAR-10 Batch 5:  Validation Accuracy at 0.7229999899864197  Loss at 0.006687851157039404
# Epoch 63, CIFAR-10 Batch 1:  Validation Accuracy at 0.7328000068664551  Loss at 0.0019346473272889853
# Epoch 63, CIFAR-10 Batch 2:  Validation Accuracy at 0.7319999933242798  Loss at 0.0028827812056988478
# Epoch 63, CIFAR-10 Batch 3:  Validation Accuracy at 0.7210000157356262  Loss at 0.005929324775934219
# Epoch 63, CIFAR-10 Batch 4:  Validation Accuracy at 0.7283999919891357  Loss at 0.006921482738107443
# Epoch 63, CIFAR-10 Batch 5:  Validation Accuracy at 0.7329999804496765  Loss at 0.005397896282374859
# Epoch 64, CIFAR-10 Batch 1:  Validation Accuracy at 0.7310000061988831  Loss at 0.002118661068379879
# Epoch 64, CIFAR-10 Batch 2:  Validation Accuracy at 0.7257999777793884  Loss at 0.002875483827665448
# Epoch 64, CIFAR-10 Batch 3:  Validation Accuracy at 0.7211999893188477  Loss at 0.005775392986834049
# Epoch 64, CIFAR-10 Batch 4:  Validation Accuracy at 0.732200026512146  Loss at 0.0077499449253082275
# Epoch 64, CIFAR-10 Batch 5:  Validation Accuracy at 0.7257999777793884  Loss at 0.0048756906762719154
# Epoch 65, CIFAR-10 Batch 1:  Validation Accuracy at 0.7250000238418579  Loss at 0.00509429257363081
# Epoch 65, CIFAR-10 Batch 2:  Validation Accuracy at 0.729200005531311  Loss at 0.003401707159355283
# Epoch 65, CIFAR-10 Batch 3:  Validation Accuracy at 0.7257999777793884  Loss at 0.005038163624703884
# Epoch 65, CIFAR-10 Batch 4:  Validation Accuracy at 0.7251999974250793  Loss at 0.014830264262855053
# Epoch 65, CIFAR-10 Batch 5:  Validation Accuracy at 0.7261999845504761  Loss at 0.00412431126460433
# Epoch 66, CIFAR-10 Batch 1:  Validation Accuracy at 0.7232000231742859  Loss at 0.0017284720670431852
# Epoch 66, CIFAR-10 Batch 2:  Validation Accuracy at 0.7264000177383423  Loss at 0.008721715770661831
# Epoch 66, CIFAR-10 Batch 3:  Validation Accuracy at 0.727400004863739  Loss at 0.004250519908964634
# Epoch 66, CIFAR-10 Batch 4:  Validation Accuracy at 0.7301999926567078  Loss at 0.0038422185461968184
# Epoch 66, CIFAR-10 Batch 5:  Validation Accuracy at 0.7287999987602234  Loss at 0.008998395875096321
# Epoch 67, CIFAR-10 Batch 1:  Validation Accuracy at 0.7192000150680542  Loss at 0.008783562108874321
# Epoch 67, CIFAR-10 Batch 2:  Validation Accuracy at 0.7235999703407288  Loss at 0.009062910452485085
# Epoch 67, CIFAR-10 Batch 3:  Validation Accuracy at 0.7210000157356262  Loss at 0.004400579258799553
# Epoch 67, CIFAR-10 Batch 4:  Validation Accuracy at 0.7300000190734863  Loss at 0.004811730235815048
# Epoch 67, CIFAR-10 Batch 5:  Validation Accuracy at 0.7296000123023987  Loss at 0.004571099765598774
# Epoch 68, CIFAR-10 Batch 1:  Validation Accuracy at 0.727400004863739  Loss at 0.004449512343853712
# Epoch 68, CIFAR-10 Batch 2:  Validation Accuracy at 0.7235999703407288  Loss at 0.007922804914414883
# Epoch 68, CIFAR-10 Batch 3:  Validation Accuracy at 0.7206000089645386  Loss at 0.005040648393332958
# Epoch 68, CIFAR-10 Batch 4:  Validation Accuracy at 0.734000027179718  Loss at 0.009419189766049385
# Epoch 68, CIFAR-10 Batch 5:  Validation Accuracy at 0.7235999703407288  Loss at 0.007453547324985266
# Epoch 69, CIFAR-10 Batch 1:  Validation Accuracy at 0.7260000109672546  Loss at 0.002756313420832157
# Epoch 69, CIFAR-10 Batch 2:  Validation Accuracy at 0.722000002861023  Loss at 0.002473236992955208
# Epoch 69, CIFAR-10 Batch 3:  Validation Accuracy at 0.7311999797821045  Loss at 0.002595554804429412
# Epoch 69, CIFAR-10 Batch 4:  Validation Accuracy at 0.7253999710083008  Loss at 0.006076359190046787
# Epoch 69, CIFAR-10 Batch 5:  Validation Accuracy at 0.7328000068664551  Loss at 0.0025538322515785694
# Epoch 70, CIFAR-10 Batch 1:  Validation Accuracy at 0.7268000245094299  Loss at 0.0032236911356449127
# Epoch 70, CIFAR-10 Batch 2:  Validation Accuracy at 0.7246000170707703  Loss at 0.015049400739371777
# Epoch 70, CIFAR-10 Batch 3:  Validation Accuracy at 0.7264000177383423  Loss at 0.004632151685655117
# Epoch 70, CIFAR-10 Batch 4:  Validation Accuracy at 0.7328000068664551  Loss at 0.0046959673054516315
# Epoch 70, CIFAR-10 Batch 5:  Validation Accuracy at 0.7289999723434448  Loss at 0.002346852794289589
# Epoch 71, CIFAR-10 Batch 1:  Validation Accuracy at 0.7355999946594238  Loss at 0.0013142551761120558
# Epoch 71, CIFAR-10 Batch 2:  Validation Accuracy at 0.7235999703407288  Loss at 0.00332639436237514
# Epoch 71, CIFAR-10 Batch 3:  Validation Accuracy at 0.7229999899864197  Loss at 0.0018436673562973738
# Epoch 71, CIFAR-10 Batch 4:  Validation Accuracy at 0.7300000190734863  Loss at 0.005085701122879982
# Epoch 71, CIFAR-10 Batch 5:  Validation Accuracy at 0.722000002861023  Loss at 0.0017454258631914854
# Epoch 72, CIFAR-10 Batch 1:  Validation Accuracy at 0.7242000102996826  Loss at 0.005713333375751972
# Epoch 72, CIFAR-10 Batch 2:  Validation Accuracy at 0.7264000177383423  Loss at 0.0035888932179659605
# Epoch 72, CIFAR-10 Batch 3:  Validation Accuracy at 0.729200005531311  Loss at 0.0010756897972896695
# Epoch 72, CIFAR-10 Batch 4:  Validation Accuracy at 0.7360000014305115  Loss at 0.00828377716243267
# Epoch 72, CIFAR-10 Batch 5:  Validation Accuracy at 0.7269999980926514  Loss at 0.0036193542182445526
# Epoch 73, CIFAR-10 Batch 1:  Validation Accuracy at 0.7328000068664551  Loss at 0.0016614611959084868
# Epoch 73, CIFAR-10 Batch 2:  Validation Accuracy at 0.7275999784469604  Loss at 0.004330902360379696
# Epoch 73, CIFAR-10 Batch 3:  Validation Accuracy at 0.7250000238418579  Loss at 0.001314450753852725
# Epoch 73, CIFAR-10 Batch 4:  Validation Accuracy at 0.729200005531311  Loss at 0.005896931979805231
# Epoch 73, CIFAR-10 Batch 5:  Validation Accuracy at 0.7196000218391418  Loss at 0.014953973703086376
# Epoch 74, CIFAR-10 Batch 1:  Validation Accuracy at 0.7233999967575073  Loss at 0.004403465893119574
# Epoch 74, CIFAR-10 Batch 2:  Validation Accuracy at 0.7235999703407288  Loss at 0.0025726421736180782
# Epoch 74, CIFAR-10 Batch 3:  Validation Accuracy at 0.7328000068664551  Loss at 0.0020110392943024635
# Epoch 74, CIFAR-10 Batch 4:  Validation Accuracy at 0.729200005531311  Loss at 0.005314717534929514
# Epoch 74, CIFAR-10 Batch 5:  Validation Accuracy at 0.7239999771118164  Loss at 0.03832365572452545
# Epoch 75, CIFAR-10 Batch 1:  Validation Accuracy at 0.730400025844574  Loss at 0.001973011065274477
# Epoch 75, CIFAR-10 Batch 2:  Validation Accuracy at 0.725600004196167  Loss at 0.0029534357599914074
# Epoch 75, CIFAR-10 Batch 3:  Validation Accuracy at 0.7235999703407288  Loss at 0.002074733842164278
# Epoch 75, CIFAR-10 Batch 4:  Validation Accuracy at 0.7279999852180481  Loss at 0.0024473548401147127
# Epoch 75, CIFAR-10 Batch 5:  Validation Accuracy at 0.7279999852180481  Loss at 0.0028102858923375607
# Epoch 76, CIFAR-10 Batch 1:  Validation Accuracy at 0.7283999919891357  Loss at 0.0020669891964644194
# Epoch 76, CIFAR-10 Batch 2:  Validation Accuracy at 0.7283999919891357  Loss at 0.0065688625909388065
# Epoch 76, CIFAR-10 Batch 3:  Validation Accuracy at 0.7297999858856201  Loss at 0.001682116067968309
# Epoch 76, CIFAR-10 Batch 4:  Validation Accuracy at 0.7311999797821045  Loss at 0.004377614241093397
# Epoch 76, CIFAR-10 Batch 5:  Validation Accuracy at 0.730400025844574  Loss at 0.002100974554196
# Epoch 77, CIFAR-10 Batch 1:  Validation Accuracy at 0.7253999710083008  Loss at 0.0027436569798737764
# Epoch 77, CIFAR-10 Batch 2:  Validation Accuracy at 0.723800003528595  Loss at 0.007969374768435955
# Epoch 77, CIFAR-10 Batch 3:  Validation Accuracy at 0.7260000109672546  Loss at 0.0019348127534613013
# Epoch 77, CIFAR-10 Batch 4:  Validation Accuracy at 0.7364000082015991  Loss at 0.01679307594895363
# Epoch 77, CIFAR-10 Batch 5:  Validation Accuracy at 0.7246000170707703  Loss at 0.0028461746405810118
# Epoch 78, CIFAR-10 Batch 1:  Validation Accuracy at 0.7275999784469604  Loss at 0.0009656641632318497
# Epoch 78, CIFAR-10 Batch 2:  Validation Accuracy at 0.7289999723434448  Loss at 0.005633173044770956
# Epoch 78, CIFAR-10 Batch 3:  Validation Accuracy at 0.7318000197410583  Loss at 0.0013262787833809853
# Epoch 78, CIFAR-10 Batch 4:  Validation Accuracy at 0.732200026512146  Loss at 0.004370138980448246
# Epoch 78, CIFAR-10 Batch 5:  Validation Accuracy at 0.722000002861023  Loss at 0.0035730109084397554
# Epoch 79, CIFAR-10 Batch 1:  Validation Accuracy at 0.73580002784729  Loss at 0.0013699744595214725
# Epoch 79, CIFAR-10 Batch 2:  Validation Accuracy at 0.7297999858856201  Loss at 0.003185319947078824
# Epoch 79, CIFAR-10 Batch 3:  Validation Accuracy at 0.7257999777793884  Loss at 0.0014626880874857306
# Epoch 79, CIFAR-10 Batch 4:  Validation Accuracy at 0.7324000000953674  Loss at 0.010393868200480938
# Epoch 79, CIFAR-10 Batch 5:  Validation Accuracy at 0.7364000082015991  Loss at 0.0011022136313840747
# Epoch 80, CIFAR-10 Batch 1:  Validation Accuracy at 0.727400004863739  Loss at 0.0027119736187160015
# Epoch 80, CIFAR-10 Batch 2:  Validation Accuracy at 0.723800003528595  Loss at 0.0077586425468325615
# Epoch 80, CIFAR-10 Batch 3:  Validation Accuracy at 0.7275999784469604  Loss at 0.00470529031008482
# Epoch 80, CIFAR-10 Batch 4:  Validation Accuracy at 0.7211999893188477  Loss at 0.004083780571818352
# Epoch 80, CIFAR-10 Batch 5:  Validation Accuracy at 0.7282000184059143  Loss at 0.001589796505868435
# Epoch 81, CIFAR-10 Batch 1:  Validation Accuracy at 0.7324000000953674  Loss at 0.0018156233709305525
# Epoch 81, CIFAR-10 Batch 2:  Validation Accuracy at 0.7296000123023987  Loss at 0.0030394692439585924
# Epoch 81, CIFAR-10 Batch 3:  Validation Accuracy at 0.7264000177383423  Loss at 0.0014960168628022075
# Epoch 81, CIFAR-10 Batch 4:  Validation Accuracy at 0.7324000000953674  Loss at 0.002125644823536277
# Epoch 81, CIFAR-10 Batch 5:  Validation Accuracy at 0.7239999771118164  Loss at 0.006618040148168802
# Epoch 82, CIFAR-10 Batch 1:  Validation Accuracy at 0.7314000129699707  Loss at 0.0011496073566377163
# Epoch 82, CIFAR-10 Batch 2:  Validation Accuracy at 0.7257999777793884  Loss at 0.002915365621447563
# Epoch 82, CIFAR-10 Batch 3:  Validation Accuracy at 0.725600004196167  Loss at 0.0025396172422915697
# Epoch 82, CIFAR-10 Batch 4:  Validation Accuracy at 0.7184000015258789  Loss at 0.01077539473772049
# Epoch 82, CIFAR-10 Batch 5:  Validation Accuracy at 0.7224000096321106  Loss at 0.0028718262910842896
# Epoch 83, CIFAR-10 Batch 1:  Validation Accuracy at 0.7170000076293945  Loss at 0.0010760214645415545
# Epoch 83, CIFAR-10 Batch 2:  Validation Accuracy at 0.7242000102996826  Loss at 0.0036892436910420656
# Epoch 83, CIFAR-10 Batch 3:  Validation Accuracy at 0.7271999716758728  Loss at 0.0016950033605098724
# Epoch 83, CIFAR-10 Batch 4:  Validation Accuracy at 0.724399983882904  Loss at 0.006165727041661739
# Epoch 83, CIFAR-10 Batch 5:  Validation Accuracy at 0.7336000204086304  Loss at 0.0012230403954163194
# Epoch 84, CIFAR-10 Batch 1:  Validation Accuracy at 0.7224000096321106  Loss at 0.0034981570206582546
# Epoch 84, CIFAR-10 Batch 2:  Validation Accuracy at 0.7232000231742859  Loss at 0.008911104872822762
# Epoch 84, CIFAR-10 Batch 3:  Validation Accuracy at 0.7268000245094299  Loss at 0.0043731024488806725
# Epoch 84, CIFAR-10 Batch 4:  Validation Accuracy at 0.7247999906539917  Loss at 0.0038460984360426664
# Epoch 84, CIFAR-10 Batch 5:  Validation Accuracy at 0.722000002861023  Loss at 0.0020182509906589985
# Epoch 85, CIFAR-10 Batch 1:  Validation Accuracy at 0.7257999777793884  Loss at 0.0034166157711297274
# Epoch 85, CIFAR-10 Batch 2:  Validation Accuracy at 0.7269999980926514  Loss at 0.004738645628094673
# Epoch 85, CIFAR-10 Batch 3:  Validation Accuracy at 0.7253999710083008  Loss at 0.0026880386285483837
# Epoch 85, CIFAR-10 Batch 4:  Validation Accuracy at 0.7289999723434448  Loss at 0.007516361773014069
# Epoch 85, CIFAR-10 Batch 5:  Validation Accuracy at 0.7229999899864197  Loss at 0.001791629591025412
# Epoch 86, CIFAR-10 Batch 1:  Validation Accuracy at 0.7214000225067139  Loss at 0.0017728361999616027
# Epoch 86, CIFAR-10 Batch 2:  Validation Accuracy at 0.7233999967575073  Loss at 0.0024813686031848192
# Epoch 86, CIFAR-10 Batch 3:  Validation Accuracy at 0.7329999804496765  Loss at 0.0011392870219424367
# Epoch 86, CIFAR-10 Batch 4:  Validation Accuracy at 0.7188000082969666  Loss at 0.003631213679909706
# Epoch 86, CIFAR-10 Batch 5:  Validation Accuracy at 0.727400004863739  Loss at 0.0010649554897099733
# Epoch 87, CIFAR-10 Batch 1:  Validation Accuracy at 0.7347999811172485  Loss at 0.001564884907566011
# Epoch 87, CIFAR-10 Batch 2:  Validation Accuracy at 0.7188000082969666  Loss at 0.002727679442614317
# Epoch 87, CIFAR-10 Batch 3:  Validation Accuracy at 0.728600025177002  Loss at 0.0014562992146238685
# Epoch 87, CIFAR-10 Batch 4:  Validation Accuracy at 0.7314000129699707  Loss at 0.003181466367095709
# Epoch 87, CIFAR-10 Batch 5:  Validation Accuracy at 0.7250000238418579  Loss at 0.0009738857042975724
# Epoch 88, CIFAR-10 Batch 1:  Validation Accuracy at 0.7215999960899353  Loss at 0.005744434893131256
# Epoch 88, CIFAR-10 Batch 2:  Validation Accuracy at 0.7260000109672546  Loss at 0.0013003277126699686
# Epoch 88, CIFAR-10 Batch 3:  Validation Accuracy at 0.725600004196167  Loss at 0.001721985056065023
# Epoch 88, CIFAR-10 Batch 4:  Validation Accuracy at 0.7251999974250793  Loss at 0.010805323719978333
# Epoch 88, CIFAR-10 Batch 5:  Validation Accuracy at 0.7307999730110168  Loss at 0.000850446056574583
# Epoch 89, CIFAR-10 Batch 1:  Validation Accuracy at 0.7300000190734863  Loss at 0.0009599972399882972
# Epoch 89, CIFAR-10 Batch 2:  Validation Accuracy at 0.7193999886512756  Loss at 0.004508450627326965
# Epoch 89, CIFAR-10 Batch 3:  Validation Accuracy at 0.7200000286102295  Loss at 0.0014199884608387947
# Epoch 89, CIFAR-10 Batch 4:  Validation Accuracy at 0.7289999723434448  Loss at 0.0012409745249897242
# Epoch 89, CIFAR-10 Batch 5:  Validation Accuracy at 0.7318000197410583  Loss at 0.0017946523148566484
# Epoch 90, CIFAR-10 Batch 1:  Validation Accuracy at 0.7283999919891357  Loss at 0.000619696278590709
# Epoch 90, CIFAR-10 Batch 2:  Validation Accuracy at 0.7332000136375427  Loss at 0.0012894980609416962
# Epoch 90, CIFAR-10 Batch 3:  Validation Accuracy at 0.7355999946594238  Loss at 0.0009248442947864532
# Epoch 90, CIFAR-10 Batch 4:  Validation Accuracy at 0.7315999865531921  Loss at 0.014081558212637901
# Epoch 90, CIFAR-10 Batch 5:  Validation Accuracy at 0.7343999743461609  Loss at 0.0017179474234580994
# Epoch 91, CIFAR-10 Batch 1:  Validation Accuracy at 0.7346000075340271  Loss at 0.0007561052334494889
# Epoch 91, CIFAR-10 Batch 2:  Validation Accuracy at 0.7307999730110168  Loss at 0.0021531081292778254
# Epoch 91, CIFAR-10 Batch 3:  Validation Accuracy at 0.7372000217437744  Loss at 0.000750811246689409
# Epoch 91, CIFAR-10 Batch 4:  Validation Accuracy at 0.7287999987602234  Loss at 0.0046847425401210785
# Epoch 91, CIFAR-10 Batch 5:  Validation Accuracy at 0.7257999777793884  Loss at 0.006121114827692509
# Epoch 92, CIFAR-10 Batch 1:  Validation Accuracy at 0.7324000000953674  Loss at 0.0017936455551534891
# Epoch 92, CIFAR-10 Batch 2:  Validation Accuracy at 0.7289999723434448  Loss at 0.002547078300267458
# Epoch 92, CIFAR-10 Batch 3:  Validation Accuracy at 0.7293999791145325  Loss at 0.0009063150500878692
# Epoch 92, CIFAR-10 Batch 4:  Validation Accuracy at 0.7279999852180481  Loss at 0.003582695033401251
# Epoch 92, CIFAR-10 Batch 5:  Validation Accuracy at 0.727400004863739  Loss at 0.002491571009159088
# Epoch 93, CIFAR-10 Batch 1:  Validation Accuracy at 0.7319999933242798  Loss at 0.001036516739986837
# Epoch 93, CIFAR-10 Batch 2:  Validation Accuracy at 0.7329999804496765  Loss at 0.0021212873980402946
# Epoch 93, CIFAR-10 Batch 3:  Validation Accuracy at 0.7279999852180481  Loss at 0.0008875353378243744
# Epoch 93, CIFAR-10 Batch 4:  Validation Accuracy at 0.7346000075340271  Loss at 0.00227547949180007
# Epoch 93, CIFAR-10 Batch 5:  Validation Accuracy at 0.725600004196167  Loss at 0.002255577128380537
# Epoch 94, CIFAR-10 Batch 1:  Validation Accuracy at 0.722000002861023  Loss at 0.0017635391559451818
# Epoch 94, CIFAR-10 Batch 2:  Validation Accuracy at 0.7260000109672546  Loss at 0.002704907674342394
# Epoch 94, CIFAR-10 Batch 3:  Validation Accuracy at 0.723800003528595  Loss at 0.0007860569166950881
# Epoch 94, CIFAR-10 Batch 4:  Validation Accuracy at 0.724399983882904  Loss at 0.001646202988922596
# Epoch 94, CIFAR-10 Batch 5:  Validation Accuracy at 0.7336000204086304  Loss at 0.0022373227402567863
# Epoch 95, CIFAR-10 Batch 1:  Validation Accuracy at 0.7257999777793884  Loss at 0.0067889392375946045
# Epoch 95, CIFAR-10 Batch 2:  Validation Accuracy at 0.7301999926567078  Loss at 0.001382246962748468
# Epoch 95, CIFAR-10 Batch 3:  Validation Accuracy at 0.7296000123023987  Loss at 0.000534872873686254
# Epoch 95, CIFAR-10 Batch 4:  Validation Accuracy at 0.7311999797821045  Loss at 0.003497184021398425
# Epoch 95, CIFAR-10 Batch 5:  Validation Accuracy at 0.7261999845504761  Loss at 0.0021668043918907642
# Epoch 96, CIFAR-10 Batch 1:  Validation Accuracy at 0.7247999906539917  Loss at 0.0013175071217119694
# Epoch 96, CIFAR-10 Batch 2:  Validation Accuracy at 0.7268000245094299  Loss at 0.004052166361361742
# Epoch 96, CIFAR-10 Batch 3:  Validation Accuracy at 0.7278000116348267  Loss at 0.0005019297823309898
# Epoch 96, CIFAR-10 Batch 4:  Validation Accuracy at 0.729200005531311  Loss at 0.005959124304354191
# Epoch 96, CIFAR-10 Batch 5:  Validation Accuracy at 0.7247999906539917  Loss at 0.009053217247128487
# Epoch 97, CIFAR-10 Batch 1:  Validation Accuracy at 0.7289999723434448  Loss at 0.0011538488324731588
# Epoch 97, CIFAR-10 Batch 2:  Validation Accuracy at 0.7242000102996826  Loss at 0.0007769749499857426
# Epoch 97, CIFAR-10 Batch 3:  Validation Accuracy at 0.7324000000953674  Loss at 0.0006418958073481917
# Epoch 97, CIFAR-10 Batch 4:  Validation Accuracy at 0.7242000102996826  Loss at 0.002250858349725604
# Epoch 97, CIFAR-10 Batch 5:  Validation Accuracy at 0.7232000231742859  Loss at 0.014899805188179016
# Epoch 98, CIFAR-10 Batch 1:  Validation Accuracy at 0.7369999885559082  Loss at 0.0010132660390809178
# Epoch 98, CIFAR-10 Batch 2:  Validation Accuracy at 0.7242000102996826  Loss at 0.004364264663308859
# Epoch 98, CIFAR-10 Batch 3:  Validation Accuracy at 0.7224000096321106  Loss at 0.0011707161320373416
# Epoch 98, CIFAR-10 Batch 4:  Validation Accuracy at 0.7337999939918518  Loss at 0.004263265989720821
# Epoch 98, CIFAR-10 Batch 5:  Validation Accuracy at 0.7332000136375427  Loss at 0.0014483784325420856
# Epoch 99, CIFAR-10 Batch 1:  Validation Accuracy at 0.7332000136375427  Loss at 0.0004951908485963941
# Epoch 99, CIFAR-10 Batch 2:  Validation Accuracy at 0.7314000129699707  Loss at 0.001243608770892024
# Epoch 99, CIFAR-10 Batch 3:  Validation Accuracy at 0.734000027179718  Loss at 0.0004526316770352423
# Epoch 99, CIFAR-10 Batch 4:  Validation Accuracy at 0.7336000204086304  Loss at 0.010737791657447815
# Epoch 99, CIFAR-10 Batch 5:  Validation Accuracy at 0.7305999994277954  Loss at 0.002353886142373085
# Epoch 100, CIFAR-10 Batch 1:  Validation Accuracy at 0.7333999872207642  Loss at 0.00190781953278929
# Epoch 100, CIFAR-10 Batch 2:  Validation Accuracy at 0.7342000007629395  Loss at 0.0008647126378491521
# Epoch 100, CIFAR-10 Batch 3:  Validation Accuracy at 0.7246000170707703  Loss at 0.001012484892271459
# Epoch 100, CIFAR-10 Batch 4:  Validation Accuracy at 0.7279999852180481  Loss at 0.007661671377718449
# Epoch 100, CIFAR-10 Batch 5:  Validation Accuracy at 0.7257999777793884  Loss at 0.0015867209294810891

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7154865506329114

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
