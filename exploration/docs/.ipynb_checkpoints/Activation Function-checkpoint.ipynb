# %% [markdown]
# # Activation Functions

# %% [markdown]
# ## Sigmoid

# %% [markdown]
# # Relu

# %% [markdown]
# # Softmax

# %%
# http://peterroelants.github.io/posts/neural_network_implementation_intermezzo02/
